# %% [markdown]
# # Vector graphics/plots

# %%
from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='model.png')

# %%
from tensorflow.keras.models import Sequential
model = Sequential()
# model.add(Embedding(max_features, output_dim=256))
# model.add(LSTM(128))
# model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# model.compile(loss='binary_crossentropy',
#               optimizer='rmsprop',
#               metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bb02c747fb12> in <module>
#       4 # model.add(LSTM(128))
#       5 # model.add(Dropout(0.5))
# ----> 6 model.add(Dense(1, activation='sigmoid'))
#       7
#       8 # model.compile(loss='binary_crossentropy',
#
# NameError: name 'Dense' is not defined

# %%
import tensorflow as tf
# mnist = tf.keras.datasets.mnist

# (x_train, y_train),(x_test, y_test) = mnist.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0

# model = tf.keras.models.Sequential([
#   tf.keras.layers.Flatten(input_shape=(28, 28)),
#   tf.keras.layers.Dense(512, activation=tf.nn.relu),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Dense(10, activation=tf.nn.softmax)
# ])

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(20, 1)),
#   tf.keras.layers.LSTM(32, input_shape=(20, 1), return_sequences=True),
    tf.keras.layers.LSTM(32, return_sequences=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True)),
    tf.keras.layers.SimpleRNN(128, return_sequences=False),
    tf.keras.layers.GaussianNoise(stddev=0.01),
    tf.keras.layers.BatchNormalization(),
#   tf.keras.layers.LSTM(32),
#   tf.keras.layers.Dense(512, activation=tf.nn.relu),
#   tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# model.fit(x_train, y_train, epochs=5)
# tf.keras.utils.plot_model(model, to_file='model.png')

tf.keras.utils.plot_model(
    model,
    to_file='deepMimo.png',
    show_shapes=True,
    show_layer_names=False,
    rankdir='TB'
#     rankdir='LR'
)

# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
import tensorflow as tf
# mnist = tf.keras.datasets.mnist

# (x_train, y_train),(x_test, y_test) = mnist.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0

# model = tf.keras.models.Sequential([
#   tf.keras.layers.Flatten(input_shape=(28, 28)),
#   tf.keras.layers.Dense(512, activation=tf.nn.relu),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Dense(10, activation=tf.nn.softmax)
# ])

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(52, 1)),
#   tf.keras.layers.LSTM(32, input_shape=(20, 1), return_sequences=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
#   tf.keras.layers.LSTM(32),
#   tf.keras.layers.Dense(512, activation=tf.nn.relu),
#   tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1, activation=tf.nn.softmax)
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# model.fit(x_train, y_train, epochs=5)
# tf.keras.utils.plot_model(model, to_file='model.png')

tf.keras.utils.plot_model(
    model,
    to_file='naiveLstm.png',
    show_shapes=True,
    show_layer_names=False,
    rankdir='TB'
#     rankdir='LR'
)

# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
# Load libraries
from keras import models
from keras import layers
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

# Start neural network
network = models.Sequential()

# Add fully connected layer with a ReLU activation function
network.add(layers.Dense(units=16, activation='relu', input_shape=(10,)))

# Add fully connected layer with a ReLU activation function
network.add(layers.Dense(units=16, activation='relu'))

# Add fully connected layer with a sigmoid activation function
network.add(layers.Dense(units=1, activation='sigmoid'))

SVG(model_to_dot(network, show_shapes=True).create(prog='dot', format='svg'))

# plot_model(network, show_shapes=True, to_file='network.png')

# %%
from keras import models
from keras import layers
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

# model = keras.models.Sequential([
#   keras.layers.Input(shape=(20, 1)),
# #   tf.keras.layers.LSTM(32, input_shape=(20, 1), return_sequences=True),
#     keras.layers.LSTM(32, return_sequences=True),
#     keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True)),
#     keras.layers.SimpleRNN(128, return_sequences=False),
#     keras.layers.GaussianNoise(stddev=0.01),
#     keras.layers.BatchNormalization(),
#   keras.layers.Dense(10, activation=tf.nn.softmax)
# ])

# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))


# Start neural network
network = models.Sequential()
# network.add(layers.LSTM(units=16, activation='relu', input_shape=(20,1)))
# network.add(layers.Dense(units=16, activation='relu'))
# network.add(layers.Dense(units=1, activation='sigmoid'))

network.add(layers.LSTM(units=128, activation='relu', input_shape=(1, 105), return_sequences=True))
network.add(layers.Bidirectional(layers.GRU(units=32, return_sequences=True)))
network.add(layers.SimpleRNN(units=32))
network.add(layers.GaussianNoise(stddev=0.01))
network.add(layers.BatchNormalization())
network.add(layers.Dense(units=46, activation='sigmoid'))

SVG(model_to_dot(network, show_shapes=True, show_layer_names=False).create(prog='dot', format='svg'))

# plot_model(network, show_shapes=True, show_layer_names=False, to_file='deepMimo.svg')

# %%
from keras import models
from keras import layers
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

# model = keras.models.Sequential([
#   keras.layers.Input(shape=(20, 1)),
# #   tf.keras.layers.LSTM(32, input_shape=(20, 1), return_sequences=True),
#     keras.layers.LSTM(32, return_sequences=True),
#     keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True)),
#     keras.layers.SimpleRNN(128, return_sequences=False),
#     keras.layers.GaussianNoise(stddev=0.01),
#     keras.layers.BatchNormalization(),
#   keras.layers.Dense(10, activation=tf.nn.softmax)
# ])

# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])
# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))


# Start neural network
network = models.Sequential()
# network.add(layers.LSTM(units=16, activation='relu', input_shape=(20,1)))
# network.add(layers.Dense(units=16, activation='relu'))
# network.add(layers.Dense(units=1, activation='sigmoid'))
# network.add(layers.LSTM(units=128, activation='relu', input_shape=(1, 52), return_sequences=True))

# network.add(layers.Bidirectional(units=128, activation='relu', input_shape=(1, 52), return_sequences=True))
network.add(layers.Bidirectional(layers.LSTM(units=64, return_sequences=True), input_shape=(1, 52)))

# network.add(layers.Bidirectional(layers.LSTM(units=32, return_sequences=True)))
network.add(layers.Dense(units=1, activation='sigmoid'))

SVG(model_to_dot(network, show_shapes=True, show_layer_names=False).create(prog='dot', format='svg'))

# plot_model(network, show_shapes=True, show_layer_names=False, to_file='naiveLstm.svg')
